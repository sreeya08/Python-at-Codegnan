# %%
#function defination
# 4. with parameters with return
def addition(a,b):
    c = a + b
    return c
    print("This statement never execute")
#function calling
x = 5
y = 10
addition(x,y)

# %%
#function defination
# 4. with parameters with return
def addition(a,b,c):
     d = a + b + c
     return d
#function calling
x = 5
y = 10
res = addition(x,y,5)
print(res)
#print(addition(10,20)) - positional argument error
# Out:
# 20

# %%
#function defination
# 3. with parameters with return
def addition(a,b):
     c = a + b
     print("This value is from Function defination block:",c)
     return
#function calling
x = 5
y = 10
res = addition(x,y)
print(res)
# Out:
# This value is from Function defination block: 15
# None

# %%
#function defination
# 2. without parameters with return
def addition():
     a = 5
     b = 20
     c = a + b
     return c
#function calling
res = addition()
print(res)
# Out:
# 25

# %%
#function defination
# 1. without parameters without return
def addition():
     a = 5
     b = 20
     c = a + b
     print("This value is from Function defination block:",c)
#function calling
res = addition()
#print(res)
# Out:
# This value is from Function defination block: 25

# %%
def pattern1(n):
    for i in range(n):
        for j in range(n):
            print("*", end="")
        print()
